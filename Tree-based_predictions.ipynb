# %% [markdown]
# # Tree-based model predictions
#
# Predictions on experimental PDFs are made here.
#
# **How to use:** Run the cells underneath from top to bottom
#
# The first cell imports packages and functions from the backend. Experimental PDFs can be loaded and the XGBoost model can predict its structure. The results from the prediction is then saved in the results folder and the fits are shown.

# %% [markdown]
# # Import packages and functions from backend

# %%
import sys, os
import xgboost as xgb

sys.path.append("Backend")

from testing import sort_filenames, get_testing_backend, load_PDFs, test_model, load_exp_pdf, plot_loaded_PDF, model_predict_cluster, fit, fit_top3
sorted_filenames_flat, xyz_path = get_testing_backend(xyz_folder_name = "natoms200")

# %% [markdown]
# # Load XGBoost model
#
# Specify the name name of the XGBoost model. The same as the folder_name in 2_Training.ipynb.

# %%
model_name = "big_seed37" #Big is a model trained on 100 PDFs per cluster with 15 PDFs per cluster in the validation and test set

model_trained = xgb.Booster({'nthread': 4})
model_trained.load_model("Models/XGBmodel_" + model_name + ".model")

# %%
#Shows the PDFs in the folder "ExperimentalData/". Set exp_filename to the desired filename and load the desired experimental PDF.
print(os.listdir("ExperimentalData"))
# Out:
# ['Cleaned', 'Au146pMBA.gr', 'JQ_S3_Pt_FCC.gr', 'Au144PET_100K-00000.gr']

# %% [markdown]
# # Tree-based predictions on Au144PET_100K-00000.gr

# %% [markdown]
# ## Load and plot experimental PDF

# %%
exp_filename = "Au144PET_100K-00000.gr"
xgrid, xyz_pdf, xyz_pdf_raw = load_exp_pdf(exp_filename)
plot_loaded_PDF(xgrid, xyz_pdf, xyz_pdf_raw, exp_filename)

# %% [markdown]
# ## Predict on experimental PDF with XGBoost model
#
# Predicts the structure of an experimental PDF. The XGBoost model predicts on the PDF as well as the Qmin, Qmax and Qdamp. Therefore, enter these values for your specific experimental PDF in the cell below. The next cell predicts with the XGBoost model, fits simulated PDFs from the top 3 predictions to the experimental PDF, plots it and saves the results and the plot to "Results/"

# %%
Qmin = 0.8   #Insert Qmin yourself
Qmax = 26    #Insert Qmax yourself
Qdamp = 0.03 #Insert Qdamp yourself - Standard Qdamp is: 0.03

# %%
indexn_list, guess_filenames, top5list = model_predict_cluster(xyz_path, xyz_pdf, exp_filename, model_trained, sorted_filenames_flat, Qmin, Qmax, Qdamp)
fit_top3(guess_filenames, xyz_path, exp_filename, Qmin, Qmax, Qdamp)
# Out:
# The model was given cluster: Au144PET_100K-00000.gr
# The model predicts the following:
# Prediction 1 with 48.3 % is: Decahedron_p_1_q_5_r_1_atom_Sc_lc_2.88.xyz
# Prediction 2 with 32.5 % is: HCP_Size1_1_Size2_4_Size3_4_atom_Sc_lc1_2.88_lc2_4.70304.xyz
# Prediction 3 with 15.0 % is: Icosahedron_shell_3_atom_Cd_lc_2.76.xyz
# Prediction 4 with 0.81 % is: HCP_Size1_1_Size2_4_Size3_4_atom_Zr_lc1_2.9_lc2_4.7357.xyz
# Prediction 5 with 0.24 % is: Decahedron_p_1_q_1_r_1_atom_Sc_lc_2.88.xyz
# The five predicted clusters have been saved to Results/Au144PET_100K-00000/
#
# Fit of the first prediction: Decahedron_p_1_q_5_r_1_atom_Sc_lc_2.88.xyz
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="8704c025-2a2f-4f7d-b347-4a3030493d62" data-root-id="1003"></div>
# Some quantities invalid due to missing profile uncertainty
# Overall (Chi2 and Reduced Chi2 invalid)
# ------------------------------------------------------------------------------
# Residual       5.44620587
# Contributions  5.44620587
# Restraints     0.00000000
# Chi2           5.44620587
# Reduced Chi2   0.00294390
# Rw             0.40977553
#
# Variables (Uncertainties invalid)
# ------------------------------------------------------------------------------
# Biso       7.51991168e-01 +/- 3.87527127e-01
# scale      1.34562231e-01 +/- 3.57164739e-02
# zoomscale  9.89917392e-01 +/- 7.78310768e-03
#
# Variable Correlations greater than 25% (Correlations invalid)
# ------------------------------------------------------------------------------
# corr(scale, Biso)   0.6881
#
# Fit of the second prediction: HCP_Size1_1_Size2_4_Size3_4_atom_Sc_lc1_2.88_lc2_4.70304.xyz
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1199">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="b9c0582e-dd2a-4f7c-9aef-5da18a0fd878" data-root-id="1200"></div>
# Some quantities invalid due to missing profile uncertainty
# Overall (Chi2 and Reduced Chi2 invalid)
# ------------------------------------------------------------------------------
# Residual       4.76253563
# Contributions  4.76253563
# Restraints     0.00000000
# Chi2           4.76253563
# Reduced Chi2   0.00257434
# Rw             0.38319348
#
# Variables (Uncertainties invalid)
# ------------------------------------------------------------------------------
# Biso       5.82604151e-01 +/- 3.04388942e-01
# scale      2.16061213e-01 +/- 5.27036159e-02
# zoomscale  9.95288442e-01 +/- 7.92967788e-03
#
# Variable Correlations greater than 25% (Correlations invalid)
# ------------------------------------------------------------------------------
# corr(scale, Biso)   0.6259
#
# Fit of the third prediction: Icosahedron_shell_3_atom_Cd_lc_2.76.xyz
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1413">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="a3d794a5-1df0-44ab-bc5c-b7a8dc819880" data-root-id="1414"></div>
# Some quantities invalid due to missing profile uncertainty
# Overall (Chi2 and Reduced Chi2 invalid)
# ------------------------------------------------------------------------------
# Residual       3.87802998
# Contributions  3.87802998
# Restraints     0.00000000
# Chi2           3.87802998
# Reduced Chi2   0.00209623
# Rw             0.34578375
#
# Variables (Uncertainties invalid)
# ------------------------------------------------------------------------------
# Biso       7.48585732e-01 +/- 4.05181071e-01
# scale      1.33271843e-01 +/- 3.34475063e-02
# zoomscale  1.00794060e+00 +/- 7.39349403e-03
#
# Variable Correlations greater than 25% (Correlations invalid)
# ------------------------------------------------------------------------------
# corr(scale, Biso)   0.6659

# %% [markdown]
# # Tree-based predictions on Au146pMBA.gr

# %% [markdown]
# ## Load and plot experimental PDF

# %%
exp_filename = "Au146pMBA.gr"
xgrid, xyz_pdf, xyz_pdf_raw = load_exp_pdf(exp_filename)
plot_loaded_PDF(xgrid, xyz_pdf, xyz_pdf_raw, exp_filename)

# %% [markdown]
# ## Predict on experimental PDF with XGBoost model
#
# Predicts the structure of an experimental PDF. The XGBoost model predicts on the PDF as well as the Qmin, Qmax and Qdamp. Therefore, enter these values for your specific experimental PDF in the cell below. The next cell predicts with the XGBoost model, fits simulated PDFs from the top 3 predictions to the experimental PDF, plots it and saves the results and the plot to "Results/"

# %%
Qmin = 1.33   #Insert Qmin yourself
Qmax = 28    #Insert Qmax yourself
Qdamp = 0.03 #Insert Qdamp yourself - Standard Qdamp is: 0.03

# %%
indexn_list, guess_filenames, top5list = model_predict_cluster(xyz_path, xyz_pdf, exp_filename, model_trained, sorted_filenames_flat, Qmin, Qmax, Qdamp)
fit_top3(guess_filenames, xyz_path, exp_filename, Qmin, Qmax, Qdamp)
# Out:
# The model was given cluster: Au146pMBA.gr
# The model predicts the following:
# Prediction 1 with 41.6 % is: FCC_h_1_k_2_l_7_atom_Hg_lc_2.78.xyz
# Prediction 2 with 22.7 % is: Decahedron_p_2_q_1_r_0_atom_Hg_lc_2.78.xyz
# Prediction 3 with 18.5 % is: Decahedron_p_1_q_2_r_1_atom_Hg_lc_2.78.xyz
# Prediction 4 with 3.59 % is: Octahedron_length_2_atom_Hg_lc_2.78.xyz
# Prediction 5 with 1.39 % is: Decahedron_p_2_q_4_r_0_atom_Hg_lc_2.78.xyz
# The five predicted clusters have been saved to Results/Au146pMBA/
#
# Fit of the first prediction: FCC_h_1_k_2_l_7_atom_Hg_lc_2.78.xyz
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1644">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="1a9dc3d0-0135-4e93-9006-f3d68ae9bba5" data-root-id="1645"></div>
# Some quantities invalid due to missing profile uncertainty
# Overall (Chi2 and Reduced Chi2 invalid)
# ------------------------------------------------------------------------------
# Residual       2.60587346
# Contributions  2.60587346
# Restraints     0.00000000
# Chi2           2.60587346
# Reduced Chi2   0.00140858
# Rw             0.29633547
#
# Variables (Uncertainties invalid)
# ------------------------------------------------------------------------------
# Biso       6.61985451e-01 +/- 3.39187457e-01
# scale      1.96158074e-01 +/- 5.14002384e-02
# zoomscale  1.02814694e+00 +/- 9.41310826e-03
#
# Variable Correlations greater than 25% (Correlations invalid)
# ------------------------------------------------------------------------------
# corr(scale, Biso)   0.6790
#
# Fit of the second prediction: Decahedron_p_2_q_1_r_0_atom_Hg_lc_2.78.xyz
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1892">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="ff2c483e-9f30-45a7-b14d-5f20aaa860d6" data-root-id="1893"></div>
# Some quantities invalid due to missing profile uncertainty
# Overall (Chi2 and Reduced Chi2 invalid)
# ------------------------------------------------------------------------------
# Residual       7.13096319
# Contributions  7.13096319
# Restraints     0.00000000
# Chi2           7.13096319
# Reduced Chi2   0.00385457
# Rw             0.49020877
#
# Variables (Uncertainties invalid)
# ------------------------------------------------------------------------------
# Biso       6.42007560e-01 +/- 3.77202826e-01
# scale      2.23895746e-01 +/- 6.18693967e-02
# zoomscale  1.02707264e+00 +/- 1.19804928e-02
#
# Variable Correlations greater than 25% (Correlations invalid)
# ------------------------------------------------------------------------------
# corr(scale, Biso)   0.6461
#
# Fit of the third prediction: Decahedron_p_1_q_2_r_1_atom_Hg_lc_2.78.xyz
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2157">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="21ebff25-fa35-4226-ae60-3019713b8213" data-root-id="2158"></div>
# Some quantities invalid due to missing profile uncertainty
# Overall (Chi2 and Reduced Chi2 invalid)
# ------------------------------------------------------------------------------
# Residual       3.39367473
# Contributions  3.39367473
# Restraints     0.00000000
# Chi2           3.39367473
# Reduced Chi2   0.00183442
# Rw             0.33817546
#
# Variables (Uncertainties invalid)
# ------------------------------------------------------------------------------
# Biso       7.06315943e-01 +/- 3.72732243e-01
# scale      1.51344580e-01 +/- 4.02941286e-02
# zoomscale  1.03059249e+00 +/- 9.26766718e-03
#
# Variable Correlations greater than 25% (Correlations invalid)
# ------------------------------------------------------------------------------
# corr(scale, Biso)   0.6800

# %% [markdown]
# # Tree-based predictions on JQ_S3_Pt_FCC.gr

# %% [markdown]
# ## Load and plot experimental PDF

# %%
exp_filename = "JQ_S3_Pt_FCC.gr"
xgrid, xyz_pdf, xyz_pdf_raw = load_exp_pdf(exp_filename)
plot_loaded_PDF(xgrid, xyz_pdf, xyz_pdf_raw, exp_filename)

# %% [markdown]
# ## Predict on experimental PDF with XGBoost model
#
# Predicts the structure of an experimental PDF. The XGBoost model predicts on the PDF as well as the Qmin, Qmax and Qdamp. Therefore, enter these values for your specific experimental PDF in the cell below. The next cell predicts with the XGBoost model, fits simulated PDFs from the top 3 predictions to the experimental PDF, plots it and saves the results and the plot to "Results/"

# %%
Qmin = 1.0   #Insert Qmin yourself
Qmax = 22    #Insert Qmax yourself
Qdamp = 0.03 #Insert Qdamp yourself - Standard Qdamp is: 0.03

# %%
indexn_list, guess_filenames, top5list = model_predict_cluster(xyz_path, xyz_pdf, exp_filename, model_trained, sorted_filenames_flat, Qmin, Qmax, Qdamp)
fit_top3(guess_filenames, xyz_path, exp_filename, Qmin, Qmax, Qdamp)
# Out:
# The model was given cluster: JQ_S3_Pt_FCC.gr
# The model predicts the following:
# Prediction 1 with 67.7 % is: Decahedron_p_4_q_1_r_1_atom_Cd_lc_2.76.xyz
# Prediction 2 with 13.8 % is: Decahedron_p_4_q_5_r_0_atom_Cd_lc_2.76.xyz
# Prediction 3 with 5.80 % is: Decahedron_p_4_q_1_r_1_atom_Hg_lc_2.78.xyz
# Prediction 4 with 4.28 % is: FCC_h_4_k_4_l_7_atom_Hg_lc_2.78.xyz
# Prediction 5 with 1.59 % is: Decahedron_p_2_q_1_r_2_atom_Cd_lc_2.76.xyz
# The five predicted clusters have been saved to Results/JQ_S3_Pt_FCC/
#
# Fit of the first prediction: Decahedron_p_4_q_1_r_1_atom_Cd_lc_2.76.xyz
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2439">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="fef29ae8-eb01-4478-973d-cff5600dead7" data-root-id="2440"></div>
# Some quantities invalid due to missing profile uncertainty
# Overall (Chi2 and Reduced Chi2 invalid)
# ------------------------------------------------------------------------------
# Residual       3.96024992
# Contributions  3.96024992
# Restraints     0.00000000
# Chi2           3.96024992
# Reduced Chi2   0.00214068
# Rw             0.29475374
#
# Variables (Uncertainties invalid)
# ------------------------------------------------------------------------------
# Biso       6.66520684e-01 +/- 2.85847398e-01
# scale      1.20957472e-01 +/- 2.64007168e-02
# zoomscale  1.00537577e+00 +/- 5.48983240e-03
#
# Variable Correlations greater than 25% (Correlations invalid)
# ------------------------------------------------------------------------------
# corr(scale, Biso)   0.7038
#
# Fit of the second prediction: Decahedron_p_4_q_5_r_0_atom_Cd_lc_2.76.xyz
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2738">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="bd7802f0-7ec7-4c99-9db7-04cd129b2e10" data-root-id="2739"></div>
# Some quantities invalid due to missing profile uncertainty
# Overall (Chi2 and Reduced Chi2 invalid)
# ------------------------------------------------------------------------------
# Residual       4.69767283
# Contributions  4.69767283
# Restraints     0.00000000
# Chi2           4.69767283
# Reduced Chi2   0.00253928
# Rw             0.32102541
#
# Variables (Uncertainties invalid)
# ------------------------------------------------------------------------------
# Biso       7.05603432e-01 +/- 2.97425103e-01
# scale      1.24544769e-01 +/- 2.78394590e-02
# zoomscale  1.00549949e+00 +/- 5.44685847e-03
#
# Variable Correlations greater than 25% (Correlations invalid)
# ------------------------------------------------------------------------------
# corr(scale, Biso)   0.7143
#
# Fit of the third prediction: Decahedron_p_4_q_1_r_1_atom_Hg_lc_2.78.xyz
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3054">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="981e58f1-f80d-47fe-848a-615853963851" data-root-id="3055"></div>
# Some quantities invalid due to missing profile uncertainty
# Overall (Chi2 and Reduced Chi2 invalid)
# ------------------------------------------------------------------------------
# Residual       3.96036672
# Contributions  3.96036672
# Restraints     0.00000000
# Chi2           3.96036672
# Reduced Chi2   0.00214074
# Rw             0.29475808
#
# Variables (Uncertainties invalid)
# ------------------------------------------------------------------------------
# Biso       6.66521708e-01 +/- 2.85845936e-01
# scale      1.20957874e-01 +/- 2.64007253e-02
# zoomscale  9.98142431e-01 +/- 5.45037748e-03
#
# Variable Correlations greater than 25% (Correlations invalid)
# ------------------------------------------------------------------------------
# corr(scale, Biso)   0.7038
