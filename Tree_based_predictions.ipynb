# %% [markdown]
# # Tree-based model predictions
#
# Predictions on experimental PDFs are made here.
#
# **How to use:** Run the cells underneath from top to bottom
#
# The first cell imports packages and functions from the backend. Experimental PDFs can be loaded and the XGBoost model can predict its structure. The results from the prediction is then saved in the results folder and the fits are shown.

# %% [markdown]
# # Import packages and functions from backend

# %%
import sys, os
import xgboost as xgb

sys.path.append("Backend")

from testing import sort_filenames, get_testing_backend, load_PDFs, test_model, load_exp_pdf, plot_PDF, plot_loaded_PDF, model_predict_cluster, fitPDF, fit, fit_top3
sorted_filenames_flat, xyz_path = get_testing_backend(xyz_folder_name = "natoms200")

# %% [markdown]
# # Load XGBoost model
#
# Specify the name name of the XGBoost model. The same as the folder_name in 2_Training.ipynb.

# %%
model_name = "big" #Big is a model trained on 100 PDFs per cluster with 15 PDFs per cluster in the validation and test set

model_trained = xgb.Booster({'nthread': 4})
model_trained.load_model("Models/XGBmodel_" + model_name + ".model")

# %%
print(os.listdir("ExperimentalData"))
# Out:
# ['Au144PET_100K-00000.gr', 'Au146pMBA.gr', 'Cleaned', 'JQ_S3_Pt_FCC.gr']

# %% [markdown]
# # Tree-based predictions on Au144PET_100K-00000.gr

# %% [markdown]
# ## Load experimental PDF
#
# Shows the PDFs in the folder "ExperimentalData/". Set exp_filename to the desired filename and load the desired experimental PDF.

# %%
exp_filename = "Au144PET_100K-00000.gr"
xgrid, xyz_pdf, xyz_pdf_raw = load_exp_pdf(exp_filename)
plot_loaded_PDF(xgrid, xyz_pdf, xyz_pdf_raw, exp_filename)

# %% [markdown]
# ## Predict on experimental PDF with XGBoost model
#
# Predicts the structure of an experimental PDF. The XGBoost model predicts on the PDF as well as the Qmin, Qmax and Qdamp. Therefore, enter these values for your specific experimental PDF in the cell below. The next cell predicts with the XGBoost model, fits simulated PDFs from the top 3 predictions to the experimental PDF, plots it and saves the results and the plot to "Results/"

# %%
Qmin = 0.8   #Insert Qmin yourself
Qmax = 26    #Insert Qmax yourself
Qdamp = 0.03 #Insert Qdamp yourself - Standard Qdamp is: 0.03

# %%
indexn_list, guess_filenames, top5list = model_predict_cluster(xyz_path, xyz_pdf, exp_filename, model_trained, sorted_filenames_flat, Qmin, Qmax, Qdamp)
fit_top3(guess_filenames, xyz_path, exp_filename, Qmin, Qmax, Qdamp)
# Out:
# The model was given cluster: Au144PET_100K-00000.gr
# The model predicts the following:
# Prediction 1 with 87.0 % is: Decahedron_p_4_q_1_r_1_atom_Tc_lc_2.54.xyz
# Prediction 2 with 1.28 % is: HCP_Size1_1_Size2_3_Size3_9_atom_Cr_lc1_2.38_lc2_3.8865399999999997.xyz
# Prediction 3 with 1.24 % is: Decahedron_p_3_q_4_r_0_atom_V_lc_2.44.xyz
# Prediction 4 with 1.09 % is: HCP_Size1_1_Size2_2_Size3_10_atom_Hg_lc1_2.78_lc2_4.53974.xyz
# Prediction 5 with 0.74 % is: Icosahedron_shell_4_atom_Cr_lc_2.38.xyz
# The five predicted clusters have been saved to Results/Au144PET_100K-00000/
#
# Fit of the first prediction: Decahedron_p_4_q_1_r_1_atom_Tc_lc_2.54.xyz
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="cc57e034-5dd0-40b0-92ea-cd5231012e3f" data-root-id="1003"></div>
# Some quantities invalid due to missing profile uncertainty
# Overall (Chi2 and Reduced Chi2 invalid)
# ------------------------------------------------------------------------------
# Residual       8.84626517
# Contributions  8.84626517
# Restraints     0.00000000
# Chi2           8.84626517
# Reduced Chi2   0.00478176
# Rw             0.52225063
#
# Variables (Uncertainties invalid)
# ------------------------------------------------------------------------------
# Biso       8.84902159e-01 +/- 4.84940830e-01
# scale      1.02986076e-01 +/- 3.02246323e-02
# zoomscale  1.11856219e+00 +/- 8.82520083e-03
#
# Variable Correlations greater than 25% (Correlations invalid)
# ------------------------------------------------------------------------------
# corr(scale, Biso)   0.7123
#
# Fit of the second prediction: HCP_Size1_1_Size2_3_Size3_9_atom_Cr_lc1_2.38_lc2_3.8865399999999997.xyz
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1199">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="f35eb762-38fb-48cc-8e97-d088122ab8e4" data-root-id="1200"></div>
# Some quantities invalid due to missing profile uncertainty
# Overall (Chi2 and Reduced Chi2 invalid)
# ------------------------------------------------------------------------------
# Residual       5.96518046
# Contributions  5.96518046
# Restraints     0.00000000
# Chi2           5.96518046
# Reduced Chi2   0.00322442
# Rw             0.42885531
#
# Variables (Uncertainties invalid)
# ------------------------------------------------------------------------------
# Biso       6.23002260e-01 +/- 3.30342064e-01
# scale      2.17024282e-01 +/- 5.45686503e-02
# zoomscale  1.20694152e+00 +/- 8.63787113e-03
#
# Variable Correlations greater than 25% (Correlations invalid)
# ------------------------------------------------------------------------------
# corr(scale, Biso)   0.6338
#
# Fit of the third prediction: Decahedron_p_3_q_4_r_0_atom_V_lc_2.44.xyz
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1413">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="498af8e0-869f-4244-84f7-5bd813044af8" data-root-id="1414"></div>
# Some quantities invalid due to missing profile uncertainty
# Overall (Chi2 and Reduced Chi2 invalid)
# ------------------------------------------------------------------------------
# Residual       6.09123577
# Contributions  6.09123577
# Restraints     0.00000000
# Chi2           6.09123577
# Reduced Chi2   0.00329256
# Rw             0.43336287
#
# Variables (Uncertainties invalid)
# ------------------------------------------------------------------------------
# Biso       7.41165185e-01 +/- 3.88552728e-01
# scale      1.28087249e-01 +/- 3.47927691e-02
# zoomscale  1.16786829e+00 +/- 9.70477606e-03
#
# Variable Correlations greater than 25% (Correlations invalid)
# ------------------------------------------------------------------------------
# corr(scale, Biso)   0.6964

# %% [markdown]
# # Tree-based predictions on Au146pMBA.gr

# %% [markdown]
# ## Load experimental PDF
#
# Shows the PDFs in the folder "ExperimentalData/". Set exp_filename to the desired filename and load the desired experimental PDF.

# %%
exp_filename = "Au146pMBA.gr"
xgrid, xyz_pdf, xyz_pdf_raw = load_exp_pdf(exp_filename)
plot_loaded_PDF(xgrid, xyz_pdf, xyz_pdf_raw, exp_filename)

# %% [markdown]
# ## Predict on experimental PDF with XGBoost model
#
# Predicts the structure of an experimental PDF. The XGBoost model predicts on the PDF as well as the Qmin, Qmax and Qdamp. Therefore, enter these values for your specific experimental PDF in the cell below. The next cell predicts with the XGBoost model, fits simulated PDFs from the top 3 predictions to the experimental PDF, plots it and saves the results and the plot to "Results/"

# %%
Qmin = 1.33   #Insert Qmin yourself
Qmax = 28     #Insert Qmax yourself
Qdamp = 0.03  #Insert Qdamp yourself - Standard Qdamp is: 0.03

# %%
indexn_list, guess_filenames, top5list = model_predict_cluster(xyz_path, xyz_pdf, exp_filename, model_trained, sorted_filenames_flat, Qmin, Qmax, Qdamp)
fit_top3(guess_filenames, xyz_path, exp_filename, Qmin, Qmax, Qdamp)
# Out:
# The model was given cluster: Au146pMBA.gr
# The model predicts the following:
# Prediction 1 with 44.7 % is: FCC_h_4_k_5_l_7_atom_Zr_lc_2.9.xyz
# Prediction 2 with 43.8 % is: Decahedron_p_2_q_2_r_0_atom_Ru_lc_2.5.xyz
# Prediction 3 with 3.00 % is: Decahedron_p_2_q_5_r_1_atom_Ti_lc_2.64.xyz
# Prediction 4 with 1.23 % is: Decahedron_p_2_q_1_r_1_atom_Hg_lc_2.78.xyz
# Prediction 5 with 0.99 % is: Octahedron_length_2_atom_Tc_lc_2.54.xyz
# The five predicted clusters have been saved to Results/Au146pMBA/
#
# Fit of the first prediction: FCC_h_4_k_5_l_7_atom_Zr_lc_2.9.xyz
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1644">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="1190ea1b-571f-45ae-9907-c6067f4710eb" data-root-id="1645"></div>
# Some quantities invalid due to missing profile uncertainty
# Overall (Chi2 and Reduced Chi2 invalid)
# ------------------------------------------------------------------------------
# Residual       7.11173195
# Contributions  7.11173195
# Restraints     0.00000000
# Chi2           7.11173195
# Reduced Chi2   0.00384418
# Rw             0.48954731
#
# Variables (Uncertainties invalid)
# ------------------------------------------------------------------------------
# Biso       1.24781659e+00 +/- 5.98620949e-01
# scale      1.01294099e-01 +/- 3.27391514e-02
# zoomscale  9.87420336e-01 +/- 6.36889505e-03
#
# Variable Correlations greater than 25% (Correlations invalid)
# ------------------------------------------------------------------------------
# corr(scale, Biso)   0.7587
#
# Fit of the second prediction: Decahedron_p_2_q_2_r_0_atom_Ru_lc_2.5.xyz
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1892">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="341181bd-b29d-430b-840a-af584c3f0f1f" data-root-id="1893"></div>
# Some quantities invalid due to missing profile uncertainty
# Overall (Chi2 and Reduced Chi2 invalid)
# ------------------------------------------------------------------------------
# Residual       4.37562057
# Contributions  4.37562057
# Restraints     0.00000000
# Chi2           4.37562057
# Reduced Chi2   0.00236520
# Rw             0.38399609
#
# Variables (Uncertainties invalid)
# ------------------------------------------------------------------------------
# Biso       6.69227983e-01 +/- 3.66422508e-01
# scale      1.95044895e-01 +/- 5.23590201e-02
# zoomscale  1.14329480e+00 +/- 1.19337383e-02
#
# Variable Correlations greater than 25% (Correlations invalid)
# ------------------------------------------------------------------------------
# corr(scale, Biso)   0.6710
#
# Fit of the third prediction: Decahedron_p_2_q_5_r_1_atom_Ti_lc_2.64.xyz
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2157">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="2d2ea606-9350-4c60-8cd8-683d9e0a6185" data-root-id="2158"></div>
# Some quantities invalid due to missing profile uncertainty
# Overall (Chi2 and Reduced Chi2 invalid)
# ------------------------------------------------------------------------------
# Residual       1.98172331
# Contributions  1.98172331
# Restraints     0.00000000
# Chi2           1.98172331
# Reduced Chi2   0.00107120
# Rw             0.25842141
#
# Variables (Uncertainties invalid)
# ------------------------------------------------------------------------------
# Biso       7.89431865e-01 +/- 3.98121845e-01
# scale      1.12040681e-01 +/- 2.99908628e-02
# zoomscale  1.08478353e+00 +/- 7.76523671e-03
#
# Variable Correlations greater than 25% (Correlations invalid)
# ------------------------------------------------------------------------------
# corr(scale, Biso)   0.7040

# %% [markdown]
# # Tree-based predictions on JQ_S3_Pt_FCC.gr

# %% [markdown]
# ## Load experimental PDF
#
# Shows the PDFs in the folder "ExperimentalData/". Set exp_filename to the desired filename and load the desired experimental PDF.

# %%
exp_filename = "JQ_S3_Pt_FCC.gr"
xgrid, xyz_pdf, xyz_pdf_raw = load_exp_pdf(exp_filename)
plot_loaded_PDF(xgrid, xyz_pdf, xyz_pdf_raw, exp_filename)

# %% [markdown]
# ## Predict on experimental PDF with XGBoost model
#
# Predicts the structure of an experimental PDF. The XGBoost model predicts on the PDF as well as the Qmin, Qmax and Qdamp. Therefore, enter these values for your specific experimental PDF in the cell below. The next cell predicts with the XGBoost model, fits simulated PDFs from the top 3 predictions to the experimental PDF, plots it and saves the results and the plot to "Results/"

# %%
Qmin = 1.0   #Insert Qmin yourself
Qmax = 22    #Insert Qmax yourself
Qdamp = 0.03 #Insert Qdamp yourself - Standard Qdamp is: 0.03

# %%
indexn_list, guess_filenames, top5list = model_predict_cluster(xyz_path, xyz_pdf, exp_filename, model_trained, sorted_filenames_flat, Qmin, Qmax, Qdamp)
fit_top3(guess_filenames, xyz_path, exp_filename, Qmin, Qmax, Qdamp)
# Out:
# The model was given cluster: JQ_S3_Pt_FCC.gr
# The model predicts the following:
# Prediction 1 with 41.0 % is: FCC_h_4_k_4_l_7_atom_Hg_lc_2.78.xyz
# Prediction 2 with 39.2 % is: FCC_h_2_k_4_l_7_atom_Cr_lc_2.38.xyz
# Prediction 3 with 4.41 % is: Decahedron_p_3_q_4_r_0_atom_Zn_lc_2.42.xyz
# Prediction 4 with 2.69 % is: Decahedron_p_3_q_2_r_0_atom_V_lc_2.44.xyz
# Prediction 5 with 1.73 % is: HCP_Size1_3_Size2_4_Size3_7_atom_Re_lc1_2.56_lc2_4.18048.xyz
# The five predicted clusters have been saved to Results/JQ_S3_Pt_FCC/
#
# Fit of the first prediction: FCC_h_4_k_4_l_7_atom_Hg_lc_2.78.xyz
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2439">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="8080d604-57af-4916-8e5d-a398fce690a1" data-root-id="2440"></div>
# Some quantities invalid due to missing profile uncertainty
# Overall (Chi2 and Reduced Chi2 invalid)
# ------------------------------------------------------------------------------
# Residual       2.54524235
# Contributions  2.54524235
# Restraints     0.00000000
# Chi2           2.54524235
# Reduced Chi2   0.00137581
# Rw             0.23629938
#
# Variables (Uncertainties invalid)
# ------------------------------------------------------------------------------
# Biso       8.21372013e-01 +/- 3.06131760e-01
# scale      1.34045741e-01 +/- 3.01769384e-02
# zoomscale  9.98318989e-01 +/- 4.62334811e-03
#
# Variable Correlations greater than 25% (Correlations invalid)
# ------------------------------------------------------------------------------
# corr(scale, Biso)   0.7358
#
# Fit of the second prediction: FCC_h_2_k_4_l_7_atom_Cr_lc_2.38.xyz
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2738">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="67416721-8330-4ec6-b723-8ab63ebbd0c6" data-root-id="2739"></div>
# Some quantities invalid due to missing profile uncertainty
# Overall (Chi2 and Reduced Chi2 invalid)
# ------------------------------------------------------------------------------
# Residual       4.50629619
# Contributions  4.50629619
# Restraints     0.00000000
# Chi2           4.50629619
# Reduced Chi2   0.00243584
# Rw             0.31441835
#
# Variables (Uncertainties invalid)
# ------------------------------------------------------------------------------
# Biso       7.77281288e-01 +/- 3.04188909e-01
# scale      1.51106497e-01 +/- 3.47193969e-02
# zoomscale  1.16624778e+00 +/- 6.04266772e-03
#
# Variable Correlations greater than 25% (Correlations invalid)
# ------------------------------------------------------------------------------
# corr(scale, Biso)   0.7339
#
# Fit of the third prediction: Decahedron_p_3_q_4_r_0_atom_Zn_lc_2.42.xyz
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3054">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="b09dec41-934d-4069-80d6-bea6c7e566e7" data-root-id="3055"></div>
# Some quantities invalid due to missing profile uncertainty
# Overall (Chi2 and Reduced Chi2 invalid)
# ------------------------------------------------------------------------------
# Residual       9.54585544
# Contributions  9.54585544
# Restraints     0.00000000
# Chi2           9.54585544
# Reduced Chi2   0.00515992
# Rw             0.45762047
#
# Variables (Uncertainties invalid)
# ------------------------------------------------------------------------------
# Biso       6.80908725e-01 +/- 3.07759710e-01
# scale      1.42350007e-01 +/- 3.30526099e-02
# zoomscale  1.14723690e+00 +/- 8.05098241e-03
#
# Variable Correlations greater than 25% (Correlations invalid)
# ------------------------------------------------------------------------------
# corr(scale, Biso)   0.6962
